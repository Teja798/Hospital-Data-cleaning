# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("c:/Users/tejes/Downloads/hospital_data_unclean.csv")
df.head()
# Out:
#             Name   Age  Gender Blood Type Medical Condition Date of Admission  \
# 0            NaN  30.0       M        B-             CANCER        2024.01.31
# 1   LEsliE tErrY  62.0       M         A+           OBESITY        2019.08.20
# 2    dAnnY SMiTH  76.0  FEMALE         A-           OBESITY        09/22/2022
# 3            NaN  28.0  FEMALE        O+           DIABETES        11/18/2020
# 4  ADRIeNNe bELL  43.0  FEMALE       AB+-            CANCER        2022.09.19
#
#                Doctor                      Hospital Insurance Provider  \
# 0    Matthew Smith ##             Sons and Miller,,         Blue Cross
# 1  Samantha Davies ##                     Kim Inc,,           Medicare
# 2                 NaN                    Cook PLC,,              Aetna
# 3      Kevin Wells ##  Hernandez Rogers and Vang,,,           Medicare
# 4   Kathleen Hanna ##                           NaN                NaN
#
# ...

# %%
df.isna().sum()
# Out:
# Name                  4440
# Age                   4440
# Gender                4440
# Blood Type            4440
# Medical Condition     4440
# Date of Admission     4440
# Doctor                4440
# Hospital              4441
# Insurance Provider    4442
# Billing Amount        4440
# Room Number           4441
# Admission Type        4440
# Discharge Date        4441
# Medication            4440
# Test Results          4440
# dtype: int64

# %%
df.shape
# Out:
# (55505, 15)

# %%
df['Name']=df['Name'].str.title()

# %%
df.sample(5)
# Out:
#                  Name   Age  Gender Blood Type Medical Condition  \
# 21291    Paul Webster  60.0  FEMALE        B-+         ARTHRITIS
# 16856    Daniel Cohen  32.0       M        O--            CANCER
# 23231  Rebecca Austin  78.0  FEMALE        B-                NaN
# 27234      David Cain  71.0  FEMALE        A+          ARTHRITIS
# 46943   Timothy Evans  58.0  FEMALE       AB-            OBESITY
#
#       Date of Admission             Doctor                     Hospital  \
# 21291        10-09-2020  Shannon Savage ##                   Inc Koch,,
# 16856        06-03-2020   Daniel Waller ##             Alvarado-Scott,,
# 23231               NaN  Alison Bennett ##  Adams, Bowers Escobar and,,
# 27234        08-04-2024       John Gill ##               Robinson Ltd,,
# 46943        22-01-2020   Peter Navarro ##     Howard and Lee, Harper,,
#
#       Insurance Provider          Billing Amount  Room Number Admission Type  \
# ...

# %%
df['Gender']=df['Gender'].replace({"M":"Male","F":"Female","FEMALE":"Female"})
df.sample(5)
# Out:
#                  Name   Age  Gender Blood Type Medical Condition  \
# 10601     Keith Woods  48.0    Male        A--            CANCER
# 31022   Patricia Lowe  73.0  Female        A-+      HYPERTENSION
# 5895    Michael Evans   NaN    Male       AB+             ASTHMA
# 22249  Joseph Sanchez  50.0  Female        B+-         ARTHRITIS
# 21399     Angel Moody  24.0  Female        O-+            ASTHMA
#
#       Date of Admission              Doctor                     Hospital  \
# 10601               NaN    Timothy Brown ##                  Brown PLC,,
# 31022        01-05-2020      Lisa Torres ##                 PLC Joseph,,
# 5895         02-01-2022     Tonya Taylor ##               PLC Shepherd,,
# 22249        2020.12.19  Rhonda Callahan ##  and Perez, Bradford Evans,,
# 21399        06/04/2022    James Woodard ##     Gentry King, Moses and,,
#
#       Insurance Provider          Billing Amount  Room Number Admission Type  \
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      25605
# Female    25460
# Name: count, dtype: int64

# %%
df['Date of Admission']=df['Date of Admission'].astype(str)
df['Discharge Date']=df['Discharge Date'].astype(str)

# %%
df.dtypes
# Out:
# Name                   object
# Age                   float64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount         object
# Room Number           float64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df['Date of Admission']=df['Date of Admission'].str.replace(".","-")
df['Date of Admission']=df['Date of Admission'].str.replace("/","-")
df['Discharge Date']=df['Discharge Date'].str.replace(".","-")
df['Discharge Date']=df['Discharge Date'].str.replace("/","-")

# %%
df[['Date of Admission','Discharge Date']].sample(5)
# Out:
#       Date of Admission Discharge Date
# 42482        11-02-2020     22-11-2020
# 15736        13-07-2019     2019-08-10
# 44424        03-28-2023     04-21-2023
# 9474         01-12-2021     12-06-2021
# 38998        18-05-2021     04-06-2021

# %%
df['Doctor']=df['Doctor'].str.replace("#","")

# %%
df['Hospital']=df['Hospital'].str.replace(",","")

# %%
df['Hospital'].sample(10)
# Out:
# 8807                     Lewis PLC
# 36524               Wilson-Maxwell
# 28409    Woodard and Reese Griffin
# 1533                     PLC Jones
# 31420                    Adams-Lee
# 15922              Summers-Mendoza
# 32318              Middleton Group
# 11440               Vazquez-Cortez
# 30246       and Greene Zavala Luna
# 41223       and Oliver Lewis Smith
# Name: Hospital, dtype: object

# %%
df['Insurance Provider'].unique()
# Out:
# array(['Blue Cross', 'Medicare', 'Aetna', nan, 'UnitedHealthcare',
#        'Cigna'], dtype=object)

# %%
df['Insurance Provider']=df['Insurance Provider'].str.replace("H"," H")

# %%
df['Insurance Provider'].unique()
# Out:
# array(['Blue Cross', 'Medicare', 'Aetna', nan, 'United Healthcare',
#        'Cigna'], dtype=object)

# %%
df.isna().sum()
# Out:
# Name                  4440
# Age                   4440
# Gender                4440
# Blood Type            4440
# Medical Condition     4440
# Date of Admission        0
# Doctor                4440
# Hospital              4441
# Insurance Provider    4442
# Billing Amount        4440
# Room Number           4441
# Admission Type        4440
# Discharge Date           0
# Medication            4440
# Test Results          4440
# dtype: int64

# %%
df['Name']=df['Name'].fillna("Unknown")

# %%
df['Name'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Age']=df['Age'].fillna(df['Age'].mean().round(2))

# %%
df['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df['Gender'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      30045
# Female    25460
# Name: count, dtype: int64

# %%
df['Blood Type']=df['Blood Type'].fillna(df['Blood Type'].mode()[0])

# %%
df['Blood Type'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Blood Type'].value_counts()
# Out:
# Blood Type
# A-      6110
# O+      1650
# B-      1644
# O-      1639
# A+      1637
# AB-     1627
# B-+     1620
# AB+-    1619
# A+-     1618
# AB-+    1618
# B+-     1613
# AB+     1613
# B-      1605
# A-      1603
# B+      1597
# B++     1588
# A--     1586
# AB++    1582
# B+      1582
# O++     1579
# A+      1576
# A++     1572
# AB+     1571
# A-+     1569
# B--     1569
# AB-     1567
# AB--    1565
# O--     1565
# O+-     1562
# O+      1557
# O-+     1556
# O-      1546
# Name: count, dtype: int64

# %%
df.sample(10)
# Out:
#                    Name   Age  Gender Blood Type Medical Condition  \
# 20618       Luis Wright  85.0    Male        A+-          DIABETES
# 2779    Jason Patterson  80.0    Male         O-      HYPERTENSION
# 45958    Sarah Marshall  42.0    Male        O-           DIABETES
# 27532     Mr. Paul Ruiz  30.0    Male        AB+          DIABETES
# 15335      Abigail Sims  61.0    Male        A+           DIABETES
# 41912  Christopher Vega  36.0    Male        B-            OBESITY
# 35776           Unknown  46.0  Female       AB++      HYPERTENSION
# 46489      Meagan Flynn  43.0  Female        A+          ARTHRITIS
# 3490        James Curry  65.0  Female        A-            OBESITY
# 25788   Brandy Reynolds  51.0  Female        A++               NaN
#
#       Date of Admission             Doctor                    Hospital  \
# 20618        04-03-2024        Cody White                  Group Adams
# 2779         2022-05-11  Claudia Martinez       and Butler King Morton
# ...

# %%
df['Doctor'].value_counts()
# Out:
# Doctor
# Michael Smith        24
# John Smith           21
# Michael Johnson      20
# Robert Smith         19
# James Smith          18
#                      ..
# Brady Burke           1
# Laura Robinson        1
# Kristen King          1
# Nicholas Schmidt      1
# Bernard Ruiz          1
# Name: count, Length: 37819, dtype: int64

# %%
df['Doctor'].isna().sum()
# Out:
# np.int64(4440)

# %%
df['Doctor']=df['Doctor'].fillna("Unknown")

# %%
df['Doctor'].isna().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df['Medical Condition']=df['Medical Condition'].fillna("Unknown")

# %%
df['Medical Condition'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Hospital'].value_counts()
# Out:
# Hospital
# LLC Smith                     38
# Ltd Smith                     36
# Smith Ltd                     36
# Smith Group                   34
# Smith Inc                     33
#                               ..
# Sullivan-Miller                1
# Velasquez-Gates                1
# Simmons Murray and Raymond     1
# and Cabrera Kim Mills          1
# Group Middleton                1
# Name: count, Length: 37356, dtype: int64

# %%
df['Hospital']=df['Hospital'].fillna("Unknown")

# %%
df['Hospital'].value_counts()
# Out:
# Hospital
# Unknown                       4441
# LLC Smith                       38
# Smith Ltd                       36
# Ltd Smith                       36
# Smith Group                     34
#                               ...
# and Moreno Crosby Young          1
# Khan-Snow                        1
# and Wilson Hampton Roberts       1
# and Gray Fleming Young           1
# Anderson-Wright                  1
# Name: count, Length: 37357, dtype: int64

# %%
df['Insurance Provider']=df['Insurance Provider'].fillna("Unknown")

# %%
df.head(10)
# Out:
#                  Name    Age  Gender Blood Type Medical Condition  \
# 0             Unknown  30.00    Male        B-             CANCER
# 1        Leslie Terry  62.00    Male         A+           OBESITY
# 2         Danny Smith  76.00  Female         A-           OBESITY
# 3             Unknown  28.00  Female        O+           DIABETES
# 4       Adrienne Bell  43.00  Female       AB+-            CANCER
# 5             Unknown  36.00    Male         A+            ASTHMA
# 6      Edward Edwards  21.00  Female       AB-           DIABETES
# 7  Christina Martinez  51.58    Male        A++           Unknown
# 8     Jasmine Aguilar  82.00    Male       AB+-           Unknown
# 9    Christopher Berg  58.00  Female       AB-+            CANCER
#
#   Date of Admission            Doctor                    Hospital  \
# 0        2024-01-31    Matthew Smith              Sons and Miller
# 1        2019-08-20  Samantha Davies                      Kim Inc
# ...

# %%
df['Billing Amount']=df['Billing Amount'].astype(str)
df['Billing Amount']=df['Billing Amount'].str.replace(" USD","")

# %%
df.head()
# Out:
#             Name   Age  Gender Blood Type Medical Condition Date of Admission  \
# 0        Unknown  30.0    Male        B-             CANCER        2024-01-31
# 1   Leslie Terry  62.0    Male         A+           OBESITY        2019-08-20
# 2    Danny Smith  76.0  Female         A-           OBESITY        09-22-2022
# 3        Unknown  28.0  Female        O+           DIABETES        11-18-2020
# 4  Adrienne Bell  43.0  Female       AB+-            CANCER        2022-09-19
#
#              Doctor                   Hospital Insurance Provider  \
# 0    Matthew Smith             Sons and Miller         Blue Cross
# 1  Samantha Davies                     Kim Inc           Medicare
# 2           Unknown                   Cook PLC              Aetna
# 3      Kevin Wells   Hernandez Rogers and Vang           Medicare
# 4   Kathleen Hanna                     Unknown            Unknown
#
#        Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df['Billing Amount']=df['Billing Amount'].astype(float).round(2)
df.sample(10)
# Out:
#                          Name    Age  Gender Blood Type Medical Condition  \
# 20660                 Unknown  69.00    Male       AB+       HYPERTENSION
# 51913             Justin Beck  72.00  Female        A-          ARTHRITIS
# 36010  Mr. Christopher Cuevas  51.58  Female         A-            ASTHMA
# 8883             Brian Greene  22.00    Male        B+           DIABETES
# 29268        Kimberly Daniels  65.00  Female        O-           DIABETES
# 52980          Lauren Goodman  51.58  Female        B-+            ASTHMA
# 2142         Charles Gonzalez  42.00  Female         O+           Unknown
# 27105            Robert Henry  27.00    Male        A+             ASTHMA
# 9151             Robert Smith  60.00  Female        A-            OBESITY
# 8805         Elizabeth Spears  82.00  Female        A-             CANCER
#
#       Date of Admission              Doctor                  Hospital  \
# 20660        05-09-2019       Carl Johnson   and Chambers Ball Taylor
# ...

# %%
df['Billing Amount'].isna().sum()
# Out:
# np.int64(4440)

# %%
df['Billing Amount']=df['Billing Amount'].fillna(df['Billing Amount'].mean())
df['Billing Amount'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Test Results'].isna().sum()
# Out:
# np.int64(4440)

# %%
df['Test Results']=df['Test Results'].fillna("Unknown")
df['Test Results']=df['Test Results'].str.replace("abn","Abnormal")
df['Test Results']=df['Test Results'].str.replace("N","Normal")

# %%
df['Test Results'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Test Results'].value_counts()
# Out:
# Test Results
# Abnormal    17123
# Normal      17039
# unknown     16903
# Unknown      4440
# Name: count, dtype: int64

# %%
df['Test Results']=df['Test Results'].str.replace("Unknown","unknown")

# %%
df['Test Results'].value_counts()
# Out:
# Test Results
# unknown     21343
# Abnormal    17123
# Normal      17039
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Name                     0
# Age                      0
# Gender                   0
# Blood Type               0
# Medical Condition        0
# Date of Admission        0
# Doctor                   0
# Hospital                 0
# Insurance Provider       0
# Billing Amount           0
# Room Number           4441
# Admission Type        4440
# Discharge Date           0
# Medication            4440
# Test Results             0
# dtype: int64

# %%
df['Medication']=df['Medication'].fillna("Unknown")

# %%
df['Room Number']=df['Room Number'].fillna("Not Assigned")

# %%
df['Admission Type'].value_counts()
# Out:
# Admission Type
# Elective     17189
# Urgent       17056
# Emergency    16820
# Name: count, dtype: int64

# %%
df['Admission Type'].isna().sum()
# Out:
# np.int64(4440)

# %%
df['Admission Type']=df['Admission Type'].fillna("Unknown")

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.dtypes
# Out:
# Name                   object
# Age                   float64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number            object
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df['Date of Admission']=df['Date of Admission'].str.strip()
df['Discharge Date']=df['Discharge Date'].str.strip()

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'], format='mixed', errors='coerce')
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'], format='mixed', errors='coerce')

# %%
df.dtypes
# Out:
# Name                          object
# Age                          float64
# Gender                        object
# Blood Type                    object
# Medical Condition             object
# Date of Admission     datetime64[ns]
# Doctor                        object
# Hospital                      object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                   object
# Admission Type                object
# Discharge Date        datetime64[ns]
# Medication                    object
# Test Results                  object
# dtype: object

# %%
df.sample(10)
# Out:
#                 Name   Age  Gender Blood Type Medical Condition  \
# 41751   Kevin Clarke  73.0    Male         B+      HYPERTENSION
# 30397   Jesse Thomas  61.0  Female        B++            ASTHMA
# 18256  Jordan Acosta  26.0  Female        O++      HYPERTENSION
# 51022  John Williams  42.0    Male         B-            ASTHMA
# 9902     Vicki Smith  19.0    Male        A++          DIABETES
# 30540  Mikayla Wiley  19.0  Female        A++      HYPERTENSION
# 4912    Jamie Thomas  34.0    Male       AB+-      HYPERTENSION
# 21459   Robert Frost  62.0    Male        B+       HYPERTENSION
# 23664   Lisa Griffin  78.0    Male        B-+      HYPERTENSION
# 17914   Cynthia Luna  77.0  Female       AB-            Unknown
#
#       Date of Admission              Doctor                   Hospital  \
# 41751        2022-12-18      Maria Whitney                Oconnor-Ross
# 30397        2023-01-10     Steven Hubbard   Alexander Wagner and Hill
# ...

# %%
df['Date of Admission'] = df['Date of Admission'].dt.strftime('%d/%m/%Y')
df['Discharge Date'] = df['Discharge Date'].dt.strftime('%d/%m/%Y')
df
# Out:
#                    Name   Age  Gender Blood Type Medical Condition  \
# 0               Unknown  30.0    Male        B-             CANCER
# 1          Leslie Terry  62.0    Male         A+           OBESITY
# 2           Danny Smith  76.0  Female         A-           OBESITY
# 3               Unknown  28.0  Female        O+           DIABETES
# 4         Adrienne Bell  43.0  Female       AB+-            CANCER
# ...                 ...   ...     ...        ...               ...
# 55500  Cassandra Carney  32.0    Male         B+      HYPERTENSION
# 55501   Dr. David Smith  18.0    Male         A+      HYPERTENSION
# 55502        Lisa Allen  65.0    Male        O--           OBESITY
# 55503       Aaron Craig  22.0  Female        O-+         ARTHRITIS
# 55504  Ashley Macdonald  36.0  Female        B+       HYPERTENSION
#
#       Date of Admission              Doctor                     Hospital  \
# 0            31/01/2024      Matthew Smith               Sons and Miller
# ...

# %%
df.isna().sum()
# Out:
# Name                     0
# Age                      0
# Gender                   0
# Blood Type               0
# Medical Condition        0
# Date of Admission     4440
# Doctor                   0
# Hospital                 0
# Insurance Provider       0
# Billing Amount           0
# Room Number              0
# Admission Type           0
# Discharge Date        4441
# Medication               0
# Test Results             0
# dtype: int64

# %%
df['Date of Admission']=df['Date of Admission'].fillna("Unknown")
df['Discharge Date']=df['Discharge Date'].fillna("Unknown")

# %%
df['Blood dup']=df['Blood Type'].str.strip()

# %%
df['Blood dup'].unique()
# Out:
# array(['B-', 'A+', 'A-', 'O+', 'AB+-', 'AB-', 'A++', 'AB-+', 'A-+', 'A+-',
#        'A--', 'B+', 'AB+', 'O-+', 'O--', 'B+-', 'B--', 'AB++', 'B-+',
#        'O++', 'O+-', 'B++', 'AB--', 'O-'], dtype=object)

# %%
df['Blood dup']=df['Blood dup'].str[:3]
df['Blood dup'].unique()
# Out:
# array(['B-', 'A+', 'A-', 'O+', 'AB+', 'AB-', 'A++', 'A-+', 'A+-', 'A--',
#        'B+', 'O-+', 'O--', 'B+-', 'B--', 'B-+', 'O++', 'O+-', 'B++', 'O-'],
#       dtype=object)

# %%
df['Blood dup']=df['Blood dup'].str.replace("++","+")
df['Blood dup']=df['Blood dup'].str.replace("--","-")
df['Blood dup']=df['Blood dup'].str.replace("+-","+")
df['Blood dup']=df['Blood dup'].str.replace("-+","-")
df[['Blood Type','Blood dup']].sample(10)
# Out:
#       Blood Type Blood dup
# 3460        AB-        AB-
# 5020          O+        O+
# 32218        O++        O+
# 14481        O+         O+
# 44214         O-        O-
# 54797        B-+        B-
# 46852        O++        O+
# 43078         O+        O+
# 2572          B+        B+
# 38129        O-+        O-

# %%
df['Blood dup'].unique()
# Out:
# array(['B-', 'A+', 'A-', 'O+', 'AB+', 'AB-', 'B+', 'O-'], dtype=object)

# %%
df.sample(5)
# Out:
#                     Name    Age  Gender Blood Type Medical Condition  \
# 2811      Allison Bowers  81.00  Female         B-           OBESITY
# 33930  Mr. Michael Smith  51.58  Female        O-+           Unknown
# 30198      Ashley Thomas  43.00  Female        A-            OBESITY
# 9564      Matthew Mendez  42.00  Female        O++            ASTHMA
# 28988     Kevin Thompson  63.00    Male        A--            CANCER
#
#       Date of Admission          Doctor                  Hospital  \
# 2811         29/03/2024      Tony Ross             Carson-Johnson
# 33930        29/01/2024  Annette Smith     Bean and Morrow Ingram
# 30198        28/09/2019  Jason Morales                Good-Martin
# 9564         11/12/2023  Courtney Reed        Valenzuela-Robinson
# 28988        26/12/2019   Taylor Perry   Nelson Hall and Williams
#
#       Insurance Provider  Billing Amount   Room Number Admission Type  \
# 2811          Blue Cross        13351.43         448.0         Urgent
# ...

# %%
df.drop('Blood Type',axis=1,inplace=True)

# %%
df.rename(columns={'Blood dup':'Blood Type'},inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Medical Condition', 'Date of Admission',
#        'Doctor', 'Hospital', 'Insurance Provider', 'Billing Amount',
#        'Room Number', 'Admission Type', 'Discharge Date', 'Medication',
#        'Test Results', 'Blood Type'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# Blood Type            0
# dtype: int64

# %%
df.dtypes
# Out:
# Name                   object
# Age                   float64
# Gender                 object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number            object
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# Blood Type             object
# dtype: object

# %%
df['Date of Admission']=pd.to_datetime(df['Date of Admission'],format='%d/%m/%Y',errors='coerce')
df['Discharge Date']=pd.to_datetime(df['Discharge Date'],format='%d/%m/%Y',errors='coerce')
df.dtypes
# Out:
# Name                          object
# Age                          float64
# Gender                        object
# Medical Condition             object
# Date of Admission     datetime64[ns]
# Doctor                        object
# Hospital                      object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                   object
# Admission Type                object
# Discharge Date        datetime64[ns]
# Medication                    object
# Test Results                  object
# Blood Type                    object
# dtype: object

# %%
df.sample(5)
# Out:
#                          Name   Age  Gender Medical Condition  \
# 48751            Nathan Greer  35.0    Male          DIABETES
# 26068          Kathryn Sawyer  26.0  Female            CANCER
# 23872  Mrs. Caitlin Daniel Md  46.0    Male      HYPERTENSION
# 6435           Heather Morris  67.0  Female         ARTHRITIS
# 47774           Noah Richards  75.0    Male           Unknown
#
#       Date of Admission             Doctor                 Hospital  \
# 48751        2019-11-23  Joshua Velasquez                 Giles Ltd
# 26068               NaT   Alicia Friedman   and Luna Castro Stevens
# 23872               NaT  Elizabeth Wilson                Newman LLC
# 6435         2023-01-19            Unknown               Ross Group
# 47774        2019-06-19     William Stout               Fox-Brennan
#
#       Insurance Provider  Billing Amount   Room Number Admission Type  \
# 48751  United Healthcare        40212.40         447.0      Emergency
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(55)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# Name                     0
# Age                      0
# Gender                   0
# Medical Condition        0
# Date of Admission     4440
# Doctor                   0
# Hospital                 0
# Insurance Provider       0
# Billing Amount           0
# Room Number              0
# Admission Type           0
# Discharge Date        4440
# Medication               0
# Test Results             0
# Blood Type               0
# dtype: int64

# %%
df['Date of Admission']=df['Date of Admission'].fillna("Unknown")
df['Discharge Date']=df['Discharge Date'].fillna("Unknown")

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# Blood Type            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# Blood Type            0
# dtype: int64

# %%
df.to_csv("c:/Users/tejes/Downloads/hospital_data_cleaned.csv",index=False)
